# %%
import os
import sys
import urllib, io
os.getcwd()
sys.path.append("..")
# sys.path.append("../utils")
sys.path.append("../../stimuli")

import numpy as np
import scipy.stats as stats
import pandas as pd

import pymongo as pm
from collections import Counter
from functools import reduce
import json
import re
import ast

from PIL import Image, ImageOps, ImageDraw, ImageFont 

from io import BytesIO
import base64

import  matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid')

from IPython.display import clear_output

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

# import drawing_utils as drawing
# import importlib
# import scoring

sys.path.append("../stimuli/towers/block_utils/")
import blockworld_utils as utils

# %%
## directory & file hierarchy
proj_dir = os.path.abspath('..')
datavol_dir = os.path.join(proj_dir,'data')
analysis_dir =  os.path.abspath('.')
results_dir = os.path.join(proj_dir,'results')
plot_dir = os.path.join(results_dir,'plots')
csv_dir = os.path.join(results_dir,'csv')
json_dir = os.path.join(results_dir,'json')
exp_dir = os.path.abspath(os.path.join(proj_dir,'behavioral_experiments'))
png_dir = os.path.abspath(os.path.join(datavol_dir,'png'))

results_csv_directory = "../results/csv"

## add helpers to python path
if os.path.join(proj_dir,'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'stimuli'))
    
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)   
    
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# %%
# set vars 
auth = pd.read_csv(os.path.join(analysis_dir,'../auth.txt'), header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org'

# have to fix this to be able to analyze from local
import pymongo as pm
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')

db = conn['lax']

# %%
# experiment_type = 'lax_tower_corpus'
# #experiment_condition = 'categorization'
# experiment_condition = 'procedural'

# experiment_name = experiment_type + '_' + experiment_condition

#iteration_name = 'corpus_dev'

# %%
# col_name = 'lax-tower-4-block-unique-silhouettes-procedural'
# col_name = 'prior_elicitation_lax_tower_4_block_unique_silhouettes_procedural_pilot_2'

col_name = 'prior_elicitation_lax_tower_4_block_unique_silhouettes'

# experiment_name = 'lax-tower-4-block-unique-silhouettes-procedural'
experiment_name = 'lax-tower-4-block-unique-silhouettes-categorization'
iteration_name = 'pilot_3'

# %%
coll = db[col_name]

# %%
# really_run = True;

# if really_run:
#     db.drop_collection(experiment_name)

# %%
                                        
# all_data[['gameID','trial_index','label']]

# %%
# # Find people who have completed all trials
# query = coll.find({"$and":[
#                         {'trialType':'normal-trial'},
#                         {'eventType':'trialEnd'},
#                         {'iterationName': { '$in': [iteration_name] }},
#                         {'trialNum': numTrials-1}]
#                      })

# complete_data_df = pd.DataFrame(query.sort('absoluteTime'))
# complete_data_ids = list(complete_data_df['gameID'])
# print(str(len(complete_data_ids)) + ' participants found')


# pd.DataFrame(coll.find({'iterationName': iteration_name}))

# %%
df_all = pd.DataFrame(coll.find({"$and":[ {'iterationName': iteration_name},
                                          {'experimentName': experiment_name}
                                         ]}))

df_all
# Out:
#                            _id  partitionFamily  splitNumber  \
# 0     611bff58655a054987de9690              0.0          0.0
# 1     611bff63655a054987de9691              NaN          NaN
# 2     611bff66655a054987de9692              0.0          1.0
# 3     611bff78655a054987de9693              0.0          2.0
# 4     611bff79655a054987de9694              NaN          NaN
# ...                        ...              ...          ...
# 1686  61241f59655a054987dea356              NaN          NaN
# 1687  61241f92655a054987dea358              NaN          NaN
# 1688  61241fd8655a054987dea35d              NaN          NaN
# 1689  61241fff655a054987dea363              NaN          NaN
# 1690  61242035655a054987dea366              NaN          NaN
#
#                                             stimNumbers  ntrials  \
# 0     [000, 011, 025, 029, 034, 041, 049, 060, 065, ...     13.0
# 1                                                   NaN      NaN
# 2     [007, 009, 019, 023, 053, 061, 062, 072, 076, ...     13.0
# 3     [024, 035, 038, 040, 052, 070, 074, 087, 093, ...     13.0
# 4                                                   NaN      NaN
# ...                                                 ...      ...
# 1686                                                NaN      NaN
# 1687                                                NaN      NaN
# 1688                                                NaN      NaN
# 1689                                                NaN      NaN
# 1690                                                NaN      NaN
#
#                                              stimGroups  numGames games  \
# 0     {'100': 'tall', '113': 'neither', '000': 'neit...       0.0    []
# 1                                                   NaN       NaN   NaN
# 2     {'106': 'neither', '115': 'tall', '007': 'neit...       0.0    []
# 3     {'110': 'neither', '126': 'tall', '129': 'tall...       0.0    []
# 4                                                   NaN       NaN   NaN
# ...                                                 ...       ...   ...
# 1686                                                NaN       NaN   NaN
# 1687                                                NaN       NaN   NaN
# 1688                                                NaN       NaN   NaN
# 1689                                                NaN       NaN   NaN
# 1690                                                NaN       NaN   NaN
#
#          experimentType                                     experimentName  \
# 0     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 2     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 3     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 4     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# ...                 ...                                                ...
# 1686  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1687  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1688  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1689  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1690  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
#
#       ...                   trial_type  trial_index time_elapsed  \
# 0     ...                          NaN          NaN          NaN
# 1     ...                external-html          0.0      10495.0
# 2     ...                          NaN          NaN          NaN
# 3     ...                          NaN          NaN          NaN
# 4     ...                external-html          0.0      18707.0
# ...   ...                          ...          ...          ...
# 1686  ...  stimuli-language-production         10.0     654188.0
# 1687  ...  stimuli-language-production         11.0     711318.0
# 1688  ...  stimuli-language-production         12.0     780994.0
# 1689  ...  stimuli-language-production         13.0     820706.0
# 1690  ...  stimuli-language-production         14.0     873732.0
#
#      internal_node_id view_history  \
# 0                 NaN          NaN
# 1             0.0-0.0          NaN
# 2                 NaN          NaN
# 3                 NaN          NaN
# 4             0.0-0.0          NaN
# ...               ...          ...
# 1686         0.0-10.0          NaN
# 1687         0.0-11.0          NaN
# 1688         0.0-12.0          NaN
# 1689         0.0-13.0          NaN
# 1690         0.0-14.0          NaN
#
#                                                   label stimId  \
# 0                                                   NaN    NaN
# 1                                                   NaN    NaN
# 2                                                   NaN    NaN
# 3                                                   NaN    NaN
# 4                                                   NaN    NaN
# ...                                                 ...    ...
# 1686  Furthest left is a blue unit horizontally. Dir...    055
# 1687  Two L's (LL)\nThere are two blue units horizon...    014
# 1688  A perfect square, with a hollow center missing...    021
# 1689  A rectangle\nFurthest left is a red unit verti...    000
# 1690  A music note.\nFurthest left is two blue units...    092
#
#                                                 stimURL  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1686  {'blocks': [{'x': 0, 'y': 0, 'height': 1, 'wid...
# 1687  {'blocks': [{'x': 0, 'y': 0, 'height': 1, 'wid...
# 1688  {'blocks': [{'x': 0, 'y': 0, 'height': 2, 'wid...
# 1689  {'blocks': [{'x': 0, 'y': 0, 'height': 2, 'wid...
# 1690  {'blocks': [{'x': 0, 'y': 0, 'height': 1, 'wid...
#
#                                               responses extra_metadata_index
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 1686  {"Q0":"Furthest left is a blue unit horizontal...                  NaN
# 1687  {"Q0":"Two L's (LL)\nThere are two blue units ...                  NaN
# 1688  {"Q0":"A perfect square, with a hollow center ...                  NaN
# 1689  {"Q0":"A rectangle\nFurthest left is a red uni...                  NaN
# 1690  {"Q0":"A music note.\nFurthest left is two blu...                  NaN
#
# [1691 rows x 32 columns]

# %% [markdown]
# ## Filter out metadata
#
# Info about stimulus set downloaded from mongo.
# Contains info about tower type.

# %%
df_meta = df_all[(df_all.datatype == 'stim_metadata') &
            (df_all.iterationName == iteration_name)]\
        [["gameID","partitionFamily","splitNumber","stimNumbers", "stimGroups",
          "numGames","experimentType","experimentName", "s3_bucket", "versionInd"]]

# %%
df_meta
# Out:
#                                          gameID  partitionFamily  splitNumber  \
# 0     4573-f484d968-a854-490d-8852-384e1abad657              0.0          0.0
# 2     8690-aeb0970d-dad0-4a98-a149-15158430b964              0.0          1.0
# 3     3038-fb85f425-c5d4-400c-808a-8903275d848b              0.0          2.0
# 6     8099-f6fa0961-8d96-4ba7-ad64-8f003e1f9764              0.0          3.0
# 9     8408-302bc471-0d6a-47de-969f-4360f2c0f2fe              0.0          4.0
# ...                                         ...              ...          ...
# 1566  2503-e5d34b8d-fc41-44b2-af2f-72aa05b774ff              1.0          4.0
# 1573  0857-029d7fb6-ba39-46c6-871a-9eb157c26da0              1.0          9.0
# 1589  2863-c4e74ec8-01f5-4f63-ab54-42cccdb14281              0.0          5.0
# 1655  9331-f1ced4b1-e145-424d-a136-8da39906352f              1.0          4.0
# 1659  7857-2849cb00-ca95-429b-8064-5e497a1f635b              1.0          4.0
#
#                                             stimNumbers  \
# 0     [000, 011, 025, 029, 034, 041, 049, 060, 065, ...
# 2     [007, 009, 019, 023, 053, 061, 062, 072, 076, ...
# 3     [024, 035, 038, 040, 052, 070, 074, 087, 093, ...
# 6     [003, 012, 026, 064, 069, 073, 077, 082, 098, ...
# 9     [002, 013, 037, 039, 042, 043, 059, 063, 092, ...
# ...                                                 ...
# 1566  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
# 1573  [007, 008, 020, 031, 041, 042, 059, 061, 065, ...
# 1589  [001, 004, 010, 030, 054, 055, 067, 071, 075, ...
# 1655  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
# 1659  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
#
#                                              stimGroups  numGames  \
# 0     {'100': 'tall', '113': 'neither', '000': 'neit...       0.0
# 2     {'106': 'neither', '115': 'tall', '007': 'neit...       0.0
# 3     {'110': 'neither', '126': 'tall', '129': 'tall...       0.0
# 6     {'101': 'tall', '103': 'neither', '108': 'neit...       0.0
# 9     {'102': 'tall', '123': 'neither', '124': 'neit...       0.0
# ...                                                 ...       ...
# 1566  {'129': 'tall', '000': 'neither', '004': 'neit...       0.0
# 1573  {'116': 'tall', '118': 'tall', '007': 'neither...       0.0
# 1589  {'109': 'tall', '001': 'wide', '004': 'neither...       1.0
# 1655  {'129': 'tall', '000': 'neither', '004': 'neit...       0.0
# 1659  {'129': 'tall', '000': 'neither', '004': 'neit...       1.0
#
#          experimentType                                     experimentName  \
# 0     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 2     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 3     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 6     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 9     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# ...                 ...                                                ...
# 1566  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1573  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1589  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1655  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1659  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
#
#                                       s3_bucket  versionInd
# 0     lax-tower-4-block-unique-silhouettes-json         0.0
# 2     lax-tower-4-block-unique-silhouettes-json         0.0
# 3     lax-tower-4-block-unique-silhouettes-json         0.0
# 6     lax-tower-4-block-unique-silhouettes-json         0.0
# 9     lax-tower-4-block-unique-silhouettes-json         0.0
# ...                                         ...         ...
# 1566  lax-tower-4-block-unique-silhouettes-json         0.0
# 1573  lax-tower-4-block-unique-silhouettes-json         0.0
# 1589  lax-tower-4-block-unique-silhouettes-json         0.0
# 1655  lax-tower-4-block-unique-silhouettes-json         0.0
# 1659  lax-tower-4-block-unique-silhouettes-json         0.0
#
# [109 rows x 10 columns]

# %% [markdown]
# ## Grab trial data

# %%
df_trial = df_all[(df_all.datatype == 'trial_end') &
             (~pd.isna(df_all.stimId)) & #has stim ID
             (df_all.iterationName == iteration_name)]\
            [['datatype', 'iterationName', 'condition',
       'config_name', 'workerID', 'gameID', 'shuffle', 'trialOrder', 'rt',
       'trial_type', 'trial_index', 'time_elapsed', 'internal_node_id',
       'view_history', 'stimId', 'stimURL', 'responses']]

# %% [markdown]
# ### Add metadata to trial data

# %%
# verify stim groups in metadata are correct
dicts = list(df_all[df_all.datatype=='stim_metadata']['stimGroups'])

stim_groups = reduce(lambda dict1, dict2: {**dict1, **dict2}, dicts)
pd.Series(list(stim_groups.values())).value_counts()

# assign stim groups from metadata (althoug)
df_trial['stim_group'] = df_trial['stimId'].apply(lambda stim: stim_groups[stim])
df_trial = df_trial.merge(df_meta, how='left', on='gameID')

# %% [markdown]
# ## Todo: get complete data sets

# %%
# find full datasets

expected_trials = 13

did_complete = df_trial.groupby(['gameID']).count()['datatype'] == expected_trials
print('complete:', len(list(did_complete[did_complete].index)))
print('incomplete:', len(list(did_complete[~did_complete].index)))

complete_dataset_gameIDs = list(did_complete[did_complete].index)

df_trial = df_trial[df_trial.gameID.isin(complete_dataset_gameIDs)]
# Out:
# complete: 104
# incomplete: 2

# %% [markdown]
# ## Data preprocessing

# %%
df_trial['labeling_task'] = df_trial['experimentName'].apply(lambda x: x.split('_')[-1])

# %% [markdown]
# #### splitting responses

# %%
# if experiment_condition == procedural: #check if prodedural (i.e. structured answers)

# %%
# df_trial['responses'] = df_trial['responses'].apply(ast.literal_eval)

# %%
# responses = df_trial['responses'][0]
# for k in responses.keys():
#     q, row = k.split('-')

# %% [markdown]
# ## Save out data

# %%
really_save = True

if really_save:
    df_trial.to_csv(results_csv_directory + '/' + experiment_name + '-' + iteration_name + '.csv')

# %%
df_trial
# Out:
#        datatype iterationName condition  \
# 0     trial_end       pilot_3       all
# 1     trial_end       pilot_3       all
# 2     trial_end       pilot_3       all
# 3     trial_end       pilot_3       all
# 4     trial_end       pilot_3       all
# ...         ...           ...       ...
# 1365  trial_end       pilot_3       all
# 1366  trial_end       pilot_3       all
# 1367  trial_end       pilot_3       all
# 1368  trial_end       pilot_3       all
# 1369  trial_end       pilot_3       all
#
#                                             config_name  \
# 0     lax-tower-4-block-unique-silhouettes-categoriz...
# 1     lax-tower-4-block-unique-silhouettes-categoriz...
# 2     lax-tower-4-block-unique-silhouettes-categoriz...
# 3     lax-tower-4-block-unique-silhouettes-categoriz...
# 4     lax-tower-4-block-unique-silhouettes-categoriz...
# ...                                                 ...
# 1365  lax-tower-4-block-unique-silhouettes-categoriz...
# 1366  lax-tower-4-block-unique-silhouettes-categoriz...
# 1367  lax-tower-4-block-unique-silhouettes-categoriz...
# 1368  lax-tower-4-block-unique-silhouettes-categoriz...
# 1369  lax-tower-4-block-unique-silhouettes-categoriz...
#
#                       workerID                                     gameID  \
# 0     6111d70e814984a27758709b  8099-f6fa0961-8d96-4ba7-ad64-8f003e1f9764
# 1     6107292349ffaa2dd36c1e56  8690-aeb0970d-dad0-4a98-a149-15158430b964
# 2     5d6da6447ef31f001e90d985  4573-f484d968-a854-490d-8852-384e1abad657
# 3     6111d70e814984a27758709b  8099-f6fa0961-8d96-4ba7-ad64-8f003e1f9764
# 4     6111d70e814984a27758709b  8099-f6fa0961-8d96-4ba7-ad64-8f003e1f9764
# ...                        ...                                        ...
# 1365  611c2569a165706dc3404885  7857-2849cb00-ca95-429b-8064-5e497a1f635b
# 1366  611c2569a165706dc3404885  7857-2849cb00-ca95-429b-8064-5e497a1f635b
# 1367  611c2569a165706dc3404885  7857-2849cb00-ca95-429b-8064-5e497a1f635b
# 1368  611c2569a165706dc3404885  7857-2849cb00-ca95-429b-8064-5e497a1f635b
# 1369  611c2569a165706dc3404885  7857-2849cb00-ca95-429b-8064-5e497a1f635b
#
#      shuffle trialOrder        rt                   trial_type  ...  \
# 0        NaN        NaN   37227.6  stimuli-language-production  ...
# 1        NaN        NaN   68354.0  stimuli-language-production  ...
# 2        NaN        NaN  117600.5  stimuli-language-production  ...
# 3        NaN        NaN   30922.1  stimuli-language-production  ...
# 4        NaN        NaN   31797.9  stimuli-language-production  ...
# ...      ...        ...       ...                          ...  ...
# 1365     NaN        NaN   63102.6  stimuli-language-production  ...
# 1366     NaN        NaN   56619.0  stimuli-language-production  ...
# 1367     NaN        NaN   69163.2  stimuli-language-production  ...
# 1368     NaN        NaN   39200.8  stimuli-language-production  ...
# 1369     NaN        NaN   52515.0  stimuli-language-production  ...
#
#       partitionFamily  splitNumber  \
# 0                 0.0          3.0
# 1                 0.0          1.0
# 2                 0.0          0.0
# 3                 0.0          3.0
# 4                 0.0          3.0
# ...               ...          ...
# 1365              1.0          4.0
# 1366              1.0          4.0
# 1367              1.0          4.0
# 1368              1.0          4.0
# 1369              1.0          4.0
#
#                                             stimNumbers  \
# 0     [003, 012, 026, 064, 069, 073, 077, 082, 098, ...
# 1     [007, 009, 019, 023, 053, 061, 062, 072, 076, ...
# 2     [000, 011, 025, 029, 034, 041, 049, 060, 065, ...
# 3     [003, 012, 026, 064, 069, 073, 077, 082, 098, ...
# 4     [003, 012, 026, 064, 069, 073, 077, 082, 098, ...
# ...                                                 ...
# 1365  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
# 1366  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
# 1367  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
# 1368  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
# 1369  [000, 004, 014, 016, 021, 024, 033, 055, 062, ...
#
#                                              stimGroups numGames  \
# 0     {'101': 'tall', '103': 'neither', '108': 'neit...      0.0
# 1     {'106': 'neither', '115': 'tall', '007': 'neit...      0.0
# 2     {'100': 'tall', '113': 'neither', '000': 'neit...      0.0
# 3     {'101': 'tall', '103': 'neither', '108': 'neit...      0.0
# 4     {'101': 'tall', '103': 'neither', '108': 'neit...      0.0
# ...                                                 ...      ...
# 1365  {'129': 'tall', '000': 'neither', '004': 'neit...      1.0
# 1366  {'129': 'tall', '000': 'neither', '004': 'neit...      1.0
# 1367  {'129': 'tall', '000': 'neither', '004': 'neit...      1.0
# 1368  {'129': 'tall', '000': 'neither', '004': 'neit...      1.0
# 1369  {'129': 'tall', '000': 'neither', '004': 'neit...      1.0
#
#          experimentType                                     experimentName  \
# 0     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 2     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 3     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 4     prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# ...                 ...                                                ...
# 1365  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1366  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1367  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1368  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
# 1369  prior_elicitation  lax-tower-4-block-unique-silhouettes-categoriz...
#
#                                       s3_bucket  versionInd  \
# 0     lax-tower-4-block-unique-silhouettes-json         0.0
# 1     lax-tower-4-block-unique-silhouettes-json         0.0
# 2     lax-tower-4-block-unique-silhouettes-json         0.0
# 3     lax-tower-4-block-unique-silhouettes-json         0.0
# 4     lax-tower-4-block-unique-silhouettes-json         0.0
# ...                                         ...         ...
# 1365  lax-tower-4-block-unique-silhouettes-json         0.0
# 1366  lax-tower-4-block-unique-silhouettes-json         0.0
# 1367  lax-tower-4-block-unique-silhouettes-json         0.0
# 1368  lax-tower-4-block-unique-silhouettes-json         0.0
# 1369  lax-tower-4-block-unique-silhouettes-json         0.0
#
#                                           labeling_task
# 0     lax-tower-4-block-unique-silhouettes-categoriz...
# 1     lax-tower-4-block-unique-silhouettes-categoriz...
# 2     lax-tower-4-block-unique-silhouettes-categoriz...
# 3     lax-tower-4-block-unique-silhouettes-categoriz...
# 4     lax-tower-4-block-unique-silhouettes-categoriz...
# ...                                                 ...
# 1365  lax-tower-4-block-unique-silhouettes-categoriz...
# 1366  lax-tower-4-block-unique-silhouettes-categoriz...
# 1367  lax-tower-4-block-unique-silhouettes-categoriz...
# 1368  lax-tower-4-block-unique-silhouettes-categoriz...
# 1369  lax-tower-4-block-unique-silhouettes-categoriz...
#
# [1352 rows x 28 columns]

# %%
# Search for a specific Prolific ID

df_all[df_all.workerID == '']
# Out:
# Empty DataFrame
# Columns: [_id, partitionFamily, splitNumber, stimNumbers, ntrials, stimGroups, numGames, games, experimentType, experimentName, s3_bucket, versionInd, datatype, iterationName, condition, config_name, workerID, gameID, shuffle, trialOrder, rt, url, trial_type, trial_index, time_elapsed, internal_node_id, view_history, label, stimId, stimURL, responses, extra_metadata_index]
# Index: []
#
# [0 rows x 32 columns]

# %%
# Find out how many times each stimulus partitions has been completed

df_trial.groupby(['partitionFamily','splitNumber']).count()/13
# Out:
#                              datatype  iterationName  condition  config_name  \
# partitionFamily splitNumber
# 0.0             0.0               5.0            5.0        5.0          5.0
#                 1.0               5.0            5.0        5.0          5.0
#                 2.0               5.0            5.0        5.0          5.0
#                 3.0               5.0            5.0        5.0          5.0
#                 4.0               5.0            5.0        5.0          5.0
#                 5.0               7.0            7.0        7.0          7.0
#                 6.0               5.0            5.0        5.0          5.0
#                 7.0               5.0            5.0        5.0          5.0
#                 8.0               5.0            5.0        5.0          5.0
#                 9.0               5.0            5.0        5.0          5.0
# 1.0             0.0               5.0            5.0        5.0          5.0
#                 1.0               5.0            5.0        5.0          5.0
#                 2.0               5.0            5.0        5.0          5.0
#                 3.0               5.0            5.0        5.0          5.0
#                 4.0               7.0            7.0        7.0          7.0
#                 5.0               5.0            5.0        5.0          5.0
#                 6.0               5.0            5.0        5.0          5.0
#                 7.0               5.0            5.0        5.0          5.0
#                 8.0               5.0            5.0        5.0          5.0
#                 9.0               5.0            5.0        5.0          5.0
#
#                              workerID  gameID  shuffle  trialOrder   rt  \
# partitionFamily splitNumber
# 0.0             0.0               5.0     5.0      0.0         0.0  5.0
#                 1.0               5.0     5.0      0.0         0.0  5.0
#                 2.0               5.0     5.0      0.0         0.0  5.0
#                 3.0               5.0     5.0      0.0         0.0  5.0
#                 4.0               5.0     5.0      0.0         0.0  5.0
#                 5.0               7.0     7.0      0.0         0.0  7.0
#                 6.0               5.0     5.0      0.0         0.0  5.0
#                 7.0               5.0     5.0      0.0         0.0  5.0
#                 8.0               5.0     5.0      0.0         0.0  5.0
#                 9.0               5.0     5.0      0.0         0.0  5.0
# 1.0             0.0               5.0     5.0      0.0         0.0  5.0
#                 1.0               5.0     5.0      0.0         0.0  5.0
#                 2.0               5.0     5.0      0.0         0.0  5.0
#                 3.0               5.0     5.0      0.0         0.0  5.0
#                 4.0               7.0     7.0      0.0         0.0  7.0
#                 5.0               5.0     5.0      0.0         0.0  5.0
#                 6.0               5.0     5.0      0.0         0.0  5.0
#                 7.0               5.0     5.0      0.0         0.0  5.0
#                 8.0               5.0     5.0      0.0         0.0  5.0
#                 9.0               5.0     5.0      0.0         0.0  5.0
#
#                              trial_type  ...  responses  stim_group  \
# partitionFamily splitNumber              ...
# 0.0             0.0                 5.0  ...        5.0         5.0
#                 1.0                 5.0  ...        5.0         5.0
#                 2.0                 5.0  ...        5.0         5.0
#                 3.0                 5.0  ...        5.0         5.0
#                 4.0                 5.0  ...        5.0         5.0
#                 5.0                 7.0  ...        7.0         7.0
#                 6.0                 5.0  ...        5.0         5.0
#                 7.0                 5.0  ...        5.0         5.0
#                 8.0                 5.0  ...        5.0         5.0
#                 9.0                 5.0  ...        5.0         5.0
# 1.0             0.0                 5.0  ...        5.0         5.0
#                 1.0                 5.0  ...        5.0         5.0
#                 2.0                 5.0  ...        5.0         5.0
#                 3.0                 5.0  ...        5.0         5.0
#                 4.0                 7.0  ...        7.0         7.0
#                 5.0                 5.0  ...        5.0         5.0
#                 6.0                 5.0  ...        5.0         5.0
#                 7.0                 5.0  ...        5.0         5.0
#                 8.0                 5.0  ...        5.0         5.0
#                 9.0                 5.0  ...        5.0         5.0
#
#                              stimNumbers  stimGroups  numGames  \
# partitionFamily splitNumber
# 0.0             0.0                  5.0         5.0       5.0
#                 1.0                  5.0         5.0       5.0
#                 2.0                  5.0         5.0       5.0
#                 3.0                  5.0         5.0       5.0
#                 4.0                  5.0         5.0       5.0
#                 5.0                  7.0         7.0       7.0
#                 6.0                  5.0         5.0       5.0
#                 7.0                  5.0         5.0       5.0
#                 8.0                  5.0         5.0       5.0
#                 9.0                  5.0         5.0       5.0
# 1.0             0.0                  5.0         5.0       5.0
#                 1.0                  5.0         5.0       5.0
#                 2.0                  5.0         5.0       5.0
#                 3.0                  5.0         5.0       5.0
#                 4.0                  7.0         7.0       7.0
#                 5.0                  5.0         5.0       5.0
#                 6.0                  5.0         5.0       5.0
#                 7.0                  5.0         5.0       5.0
#                 8.0                  5.0         5.0       5.0
#                 9.0                  5.0         5.0       5.0
#
#                              experimentType  experimentName  s3_bucket  \
# partitionFamily splitNumber
# 0.0             0.0                     5.0             5.0        5.0
#                 1.0                     5.0             5.0        5.0
#                 2.0                     5.0             5.0        5.0
#                 3.0                     5.0             5.0        5.0
#                 4.0                     5.0             5.0        5.0
#                 5.0                     7.0             7.0        7.0
#                 6.0                     5.0             5.0        5.0
#                 7.0                     5.0             5.0        5.0
#                 8.0                     5.0             5.0        5.0
#                 9.0                     5.0             5.0        5.0
# 1.0             0.0                     5.0             5.0        5.0
#                 1.0                     5.0             5.0        5.0
#                 2.0                     5.0             5.0        5.0
#                 3.0                     5.0             5.0        5.0
#                 4.0                     7.0             7.0        7.0
#                 5.0                     5.0             5.0        5.0
#                 6.0                     5.0             5.0        5.0
#                 7.0                     5.0             5.0        5.0
#                 8.0                     5.0             5.0        5.0
#                 9.0                     5.0             5.0        5.0
#
#                              versionInd  labeling_task
# partitionFamily splitNumber
# 0.0             0.0                 5.0            5.0
#                 1.0                 5.0            5.0
#                 2.0                 5.0            5.0
#                 3.0                 5.0            5.0
#                 4.0                 5.0            5.0
#                 5.0                 7.0            7.0
#                 6.0                 5.0            5.0
#                 7.0                 5.0            5.0
#                 8.0                 5.0            5.0
#                 9.0                 5.0            5.0
# 1.0             0.0                 5.0            5.0
#                 1.0                 5.0            5.0
#                 2.0                 5.0            5.0
#                 3.0                 5.0            5.0
#                 4.0                 7.0            7.0
#                 5.0                 5.0            5.0
#                 6.0                 5.0            5.0
#                 7.0                 5.0            5.0
#                 8.0                 5.0            5.0
#                 9.0                 5.0            5.0
#
# [20 rows x 26 columns]
