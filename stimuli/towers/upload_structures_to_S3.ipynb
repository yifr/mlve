# %% [markdown]
# # Upload tower stimuli to s3

# %%
#Which experiment? bucket_name is the name of the experiment and will be name of the databases both on mongoDB and S3

bucket_name = 'lax-structures-bridge-all' #containment
stim_version = 'lax-structures-bridge-all'

ext = 'png'

# composites (includes ambiguous stims twice)
# bucket_name = 'lax-tower-4-block-unique-silhouettes-composites-json' #containment
# stim_version = 'tower_4_block_unique_silhouettes_composites_json'

# %%
import os
from glob import glob
import boto3
import botocore
from IPython.display import clear_output
import json
import pandas as pd
from PIL import Image

# %%
def list_files(paths, ext=ext):
    """Pass list of folders if there are stimuli in multiple folders. 
    Make sure that the containing folder is informative, as the rest of the path is ignored in naming. 
    Also returns filenames as uploaded to S3"""
    if type(paths) is not list:
        paths = [paths]
    results = []
    names = []
    for path in paths:
        results += [y for x in os.walk(path) for y in glob(os.path.join(x[0], '*.%s' % ext))]
        names += [os.path.split(y)[1] for x in os.walk(path) for y in glob(os.path.join(x[0], '*.%s' % ext))]
    return results,names

# %%
## helper to speed things up by not uploading images if they already exist, can be overriden 
def check_exists(s3, bucket_name, stim_name):
    try:
        s3.Object(bucket_name,stim_name).load()    
        return True
    except botocore.exceptions.ClientError as e:    
        if (e.response['Error']['Code'] == "404"):
            print('The object does not exist.')
            return False
        else:
            print('Something else has gone wrong with {}'.format(stim_name))

# %% [markdown]
# Pass list of folders if there are stimuli in multiple folders. Make sure that the containing folder is informative, as the rest of the path is ignored in naming.

# %%
## set up paths, etc.
# paths_to_stim = ['./example'] ## provide a list of full paths here.
paths_to_stim = [
    
    # tower silhouettes
    "./" + stim_version,
    
]

# paths_to_stim = glob.glob()
full_stim_paths, filenames = [x for x in list_files(paths_to_stim) if x !='.DS_Store'] #generate filenames and stimpaths
print('We have {} stimuli to upload.'.format(len(full_stim_paths)))
# Out:
# We have 250 stimuli to upload.

# %% [markdown]
# Upload to S3. This expects the `.aws/credentials` file in your home directory.

# %%
reallyRun = True
if reallyRun:

    ## establish connection to s3 
    s3 = boto3.resource('s3')

    ## create a bucket with the appropriate bucket name
    try: 
        b = s3.create_bucket(Bucket=bucket_name) 
        print('Created new bucket.')
#     except NoCredentialsError:
#         print("Credential missing") #.aws/credentials should be in home folder, not in repo folder
    except:
        b = s3.Bucket(bucket_name)
        print('Bucket already exists.')

    ## do we want to overwrite files on s3?
    overwrite = True
    
    ## set bucket and objects to public
    b.Acl().put(ACL='public-read') ## sets bucket to public

    ## now let's loop through stim paths and actually upload to s3 (woot!)
    for i,path_to_file in enumerate(full_stim_paths):        # use sorted(full_stim_paths) when not using photodraw32
        stim_name = filenames[i]
        if ((check_exists(s3, bucket_name, stim_name)==False) | (overwrite==True)):
            print('Now uploading {} as {} | {} of {}'.format(os.path.split(path_to_file)[-1],stim_name,(i+1),len(full_stim_paths)))
            s3.Object(bucket_name,stim_name).put(Body=open(path_to_file,'rb')) ## upload stimuli
            s3.Object(bucket_name,stim_name).Acl().put(ACL='public-read') ## set access controls
        else: 
            print('Skipping {} | {} of {} because it already exists.'.format(os.path.split(path_to_file)[-1],(i+1),len(full_stim_paths)))
        clear_output(wait=True)
print('Done!')
# Out:
# Done!

# %%
for my_bucket_object in b.objects.all():
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='df_bridge.csv')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-000-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-001-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-002-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-003-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-004-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-005-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-006-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-007-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-008-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-009-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-010-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-011-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-012-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-013-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-014-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-015-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-016-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-017-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-018-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-019-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-020-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-021-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-022-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-023-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-024-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-025-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-026-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-027-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-028-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-029-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-030-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-031-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-032-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-033-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-034-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-035-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-036-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-037-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-038-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-039-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-040-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-041-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-042-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-043-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-044-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-045-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-046-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-047-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-048-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-049-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-050-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-051-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-052-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-053-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-054-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-055-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-056-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-057-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-058-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-059-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-060-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-061-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-062-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-063-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-064-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-065-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-066-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-067-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-068-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-069-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-070-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-071-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-072-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-073-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-074-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-075-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-076-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-077-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-078-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-079-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-080-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-081-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-082-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-083-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-084-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-085-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-086-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-087-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-088-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-089-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-090-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-091-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-092-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-093-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-094-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-095-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-096-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-097-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-098-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-099-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-100-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-101-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-102-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-103-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-104-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-105-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-106-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-107-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-108-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-109-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-110-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-111-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-112-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-113-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-114-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-115-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-116-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-117-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-118-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-119-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-120-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-121-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-122-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-123-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-124-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-125-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-126-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-127-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-128-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-129-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-130-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-131-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-132-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-133-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-134-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-135-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-136-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-137-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-138-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-139-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-140-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-141-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-142-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-143-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-144-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-145-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-146-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-147-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-148-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-149-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-150-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-151-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-152-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-153-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-154-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-155-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-156-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-157-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-158-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-159-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-160-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-161-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-162-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-163-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-164-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-165-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-166-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-167-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-168-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-169-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-170-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-171-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-172-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-173-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-174-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-175-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-176-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-177-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-178-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-179-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-180-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-181-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-182-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-183-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-184-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-185-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-186-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-187-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-188-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-189-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-190-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-191-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-192-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-193-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-194-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-195-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-196-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-197-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-198-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-199-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-200-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-201-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-202-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-203-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-204-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-205-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-206-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-207-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-208-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-209-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-210-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-211-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-212-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-213-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-214-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-215-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-216-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-217-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-218-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-219-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-220-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-221-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-222-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-223-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-224-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-225-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-226-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-227-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-228-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-229-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-230-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-231-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-232-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-233-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-234-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-235-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-236-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-237-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-238-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-239-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-240-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-241-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-242-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-243-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-244-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-245-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-246-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-247-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-248-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-bridge-all', key='lax-structures-bridge-249-all.png')

# %%
### add burn-in trials

# %%
### add catch trials
