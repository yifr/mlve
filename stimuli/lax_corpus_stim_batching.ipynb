# %% [markdown]
# # Stimulus batching
#
# Creates metadata for corpus collection on gadget and structure domains.
#
# Partitions train/test data into batches of 25 stimuli (20 train and 5 test).
#
# Multiple families of batches can be specified.

# %%
from __future__ import division

import numpy as np
import os, sys
from PIL import Image
import pandas as pd
import json
import pickle

from matplotlib import pylab, mlab, pyplot
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.path import Path
import matplotlib.patches as patches
# %matplotlib inline

from IPython.core.pylabtools import figsize, getfigs

import seaborn as sns
from sklearn.model_selection import StratifiedKFold

import random

from scipy.stats import norm
from IPython.display import clear_output

import copy
import importlib

# import urllib library
from urllib.request import urlopen

### Add Paths

## root paths
curr_dir = os.getcwd()
proj_dir = os.path.abspath(os.path.join(curr_dir,'..')) ## u\e relative paths

## add helpers to python path
import sys
if os.path.join(proj_dir, 'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir, 'stimuli'))

# %% [markdown]
# ### Data storage setup

# %%
s3_bucket_path_template = "https://lax-{}-{}-all.s3.amazonaws.com/"

# %% [markdown]
# ### Structure setup

# %%
domain = 'structures'
subdomains = ['bridge', 'castle', 'house', 'city']

# select subdomain
subdomain = subdomains[1]

# %% [markdown]
# ### Gadgets setup

# %%
domain = 'drawing'
subdomains = ['nuts-bolts','wheels','furniture','dials']

# select subdomain
subdomain = subdomains[0]

# %% [markdown]
# ### Get stimulus data

# %%
experiment_name = 'lax_{}_{}_all'.format(domain, subdomain)

# generate bucket path
s3_bucket_path = s3_bucket_path_template.format(domain, subdomain)

if domain == 'structures':
    # read manifest data
    df = pd.read_csv(s3_bucket_path + 'df_{}.csv'.format(subdomain))

    # assign grouping column
    df['group'] = np.where(df['train'], 'train', 'test')

    # assign id column
    df['stim_id'] = df['structure_number'] 
    
    
elif domain == 'drawing':
    
    # read manifest data
    df = pd.read_csv(s3_bucket_path + 'manifest.csv'.format(subdomain))
    
    # assign grouping column
    df['group'] = df['data_split']

    # assign id column
    df['stim_id'] = df['stim_id'].apply(lambda x: x[-3:])

# %%
df
# Out:
#      Unnamed: 0 structure_type  \
# 0             0         castle
# 1             1         castle
# 2             2         castle
# 3             3         castle
# 4             4         castle
# ..          ...            ...
# 245         245         castle
# 246         246         castle
# 247         247         castle
# 248         248         castle
# 249         249         castle
#
#                                                 blocks  structure_width  \
# 0    [{'x': 0, 'y': 0, 'height': 1, 'width': 2}, {'...             14.0
# 1    [{'x': 1, 'y': 0, 'height': 2, 'width': 1}, {'...             16.0
# 2    [{'x': 1, 'y': 0, 'height': 2, 'width': 1}, {'...             16.0
# 3    [{'x': 0, 'y': 0, 'height': 1, 'width': 2}, {'...             16.0
# 4    [{'x': 0, 'y': 0, 'height': 1, 'width': 2}, {'...             14.0
# ..                                                 ...              ...
# 245  [{'x': 0, 'y': 0, 'height': 1, 'width': 2}, {'...             20.0
# 246  [{'x': 0, 'y': 0, 'height': 2, 'width': 1}, {'...             20.0
# 247  [{'x': 1, 'y': 0, 'height': 2, 'width': 1}, {'...             20.0
# 248  [{'x': 0, 'y': 0, 'height': 1, 'width': 2}, {'...             20.0
# 249  [{'x': 1, 'y': 0, 'height': 2, 'width': 1}, {'...             20.0
#
#      structure_height  n_blocks  wall_height  wall_size  tower_height  \
# 0                 7.0      40.0          1.0        2.0           1.0
# 1                 8.0      37.0          1.0        2.0           1.0
# 2                 8.0      41.0          1.0        2.0           1.0
# 3                11.0      45.0          1.0        2.0           1.0
# 4                 7.0      32.0          1.0        2.0           1.0
# ..                ...       ...          ...        ...           ...
# 245              18.0     107.0          4.0        4.0           1.0
# 246              18.0      99.0          4.0        4.0           1.0
# 247              18.0     107.0          4.0        4.0           2.0
# 248              18.0     127.0          4.0        4.0           3.0
# 249              18.0     123.0          4.0        4.0           4.0
#
#     roof_name  central_roof_size  tower_roof_size  \
# 0        dome                6.0              4.0
# 1        dome                8.0              4.0
# 2        dome                8.0              4.0
# 3        dome                8.0              4.0
# 4        dome                6.0              4.0
# ..        ...                ...              ...
# 245   pyramid               12.0              4.0
# 246   pyramid               12.0              4.0
# 247   pyramid               12.0              4.0
# 248   pyramid               12.0              4.0
# 249   pyramid               12.0              4.0
#
#                                     dreamcoder_program  \
# 0    (h h (r 1) t (l 2) t (r 6) t (l 2) t (r 1) h h...
# 1    ((r 1) t (r 3) h (l 1) t (l 3) h (r 2) h (l 2)...
# 2    ((r 1) t (r 2) t (l 3) h (r 4) h (l 2) h (l 2)...
# 3    (h (r 3) t (l 4) t (r 5) h (l 2) h (l 2) h (r ...
# 4    (h (r 3) t (l 4) t (r 5) h (l 2) h (l 2) h (r ...
# ..                                                 ...
# 245  (h (r 4) h (l 5) t t (r 6) t t (l 5) h (r 4) h...
# 246  ((l 1) t (r 6) t (l 5) h (r 4) h (l 4) h (r 4)...
# 247  ((r 1) t (r 2) t (l 3) h (r 4) h (l 3) t (r 2)...
# 248  (h (r 4) h (l 5) t (r 6) t (l 5) h (r 4) h (l ...
# 249  ((r 1) t (r 3) h (l 1) t (l 3) h (r 1) t (r 3)...
#
#                                  program_whole_squares  structure_number  \
# 0    (h h (r 1) t (l 1) t (r 3) t (l 1) t h h (l 1)...                 0
# 1    ((r 1) t (r 1) h t (l 2) h (r 1) h (l 1) h (r ...                 1
# 2    ((r 1) t (r 1) t (l 2) h (r 2) h (l 1) h (l 1)...                 2
# 3    (h (r 2) t (l 2) t (r 2) h (l 1) h (l 1) h (r ...                 3
# 4    (h (r 2) t (l 2) t (r 2) h (l 1) h (l 1) h (r ...                 4
# ..                                                 ...               ...
# 245  (h (r 2) h (l 2) t t (r 3) t t (l 3) h (r 2) h...               245
# 246  (t (r 3) t (l 3) h (r 2) h (l 2) h (r 2) h (l ...               246
# 247  ((r 1) t (r 1) t (l 2) h (r 2) h (l 1) t (r 1)...               247
# 248  (h (r 2) h (l 2) t (r 3) t (l 3) h (r 2) h (l ...               248
# 249  ((r 1) t (r 1) h t (l 2) h (r 1) t (r 1) h t (...               249
#
#      train  group  stim_id
# 0     True  train        0
# 1     True  train        1
# 2     True  train        2
# 3     True  train        3
# 4     True  train        4
# ..     ...    ...      ...
# 245   True  train      245
# 246  False   test      246
# 247   True  train      247
# 248   True  train      248
# 249   True  train      249
#
# [250 rows x 18 columns]

# %% [markdown]
# ## Generate splits

# %%
groups = df[['stim_id','group']]
groups['group'].value_counts()
# Out:
# train    200
# test      50
# Name: group, dtype: int64

# %%
n_families = 1
n_splits = 10
X = df['stim_id']
y = df['group']

for i in range(0, n_families):
    
    # set up partitioning
    skf = StratifiedKFold(n_splits=n_splits, 
                          random_state=i,  # tie random state to group num
                          shuffle=True)
    
    # apply partitioning and save to df
    for split_num, (train_index, test_index) in enumerate(skf.split(X, y)):
        df.loc[test_index,'family_'+str(i)] = split_num
#         print(groups.loc[test_index])

# %% [markdown]
# ## To run multiple versions, upload the same metadate to separate collections, and update stimColName in configs accordingly

# %%
versionInd = 0

# %%
# connect to mongo

import pymongo as pm

# set vars 
auth = pd.read_csv('../auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org' ## experiment server ip address

conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['stimuli']
coll = db[experiment_name]

# %%
s3_bucket_path
# Out:
# 'https://lax-drawing-furniture-all.s3.amazonaws.com/'

# %%
# convert to lists of stimulus names

metadata = []

for f in range(0, n_families):
    for s in range(0,n_splits):
        stimIDs = list(df.groupby('family_'+str(f)).get_group(s)['stim_id'].apply(lambda x: str(x).zfill(3)))
#         print(stim_numbers)
        metadata.append(
            {
                'partitionFamily': f,
                'splitNumber': s,
                'stimIDs': stimIDs,
                'stimURLS': [s3_bucket_path + "lax-{}-{}-{}-all.png".format(domain,
                                                              subdomain,
                                                              stimID) for stimID in stimIDs],
                'ntrials': len(stimIDs),
                'stimGroups': {n: df.groupby('family_'+str(f)).get_group(s).reset_index().loc[i,'group'] for i, n in enumerate(stimIDs)},
                'numGames': 0,
                'games': [],
                'experimentType': 'corpus_collection',
                'experimentName': experiment_name,
                's3_bucket_url': s3_bucket_path,
                'versionInd': versionInd
            })

# %%
metadata
# Out:
# [{'partitionFamily': 0,
#   'splitNumber': 0,
#   'stimIDs': ['004',
#    '009',
#    '034',
#    '046',
#    '047',
#    '056',
#    '070',
#    '071',
#    '090',
#    '094',
#    '111',
#    '113',
#    '126',
#    '132',
#    '143',
#    '145',
#    '154',
#    '161',
#    '166',
#    '171',
#    '199',
#    '216',
#    '228',
#    '235',
#    '243'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-004-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-009-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-034-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-046-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-047-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-056-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-070-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-071-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-090-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-094-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-111-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-113-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-126-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-132-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-143-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-145-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-154-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-161-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-166-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-171-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-199-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-216-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-228-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-235-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-243-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'004': 'test',
#    '009': 'test',
#    '034': 'test',
#    '046': 'test',
#    '047': 'test',
#    '056': 'train',
#    '070': 'train',
#    '071': 'train',
#    '090': 'train',
#    '094': 'train',
#    '111': 'train',
#    '113': 'train',
#    '126': 'train',
#    '132': 'train',
#    '143': 'train',
#    '145': 'train',
#    '154': 'train',
#    '161': 'train',
#    '166': 'train',
#    '171': 'train',
#    '199': 'train',
#    '216': 'train',
#    '228': 'train',
#    '235': 'train',
#    '243': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimIDs': ['015',
#    '027',
#    '030',
#    '038',
#    '043',
#    '058',
#    '074',
#    '079',
#    '084',
#    '091',
#    '119',
#    '122',
#    '123',
#    '124',
#    '138',
#    '147',
#    '148',
#    '158',
#    '172',
#    '175',
#    '197',
#    '208',
#    '231',
#    '237',
#    '244'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-015-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-027-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-030-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-038-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-043-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-058-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-074-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-079-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-084-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-091-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-119-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-122-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-123-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-124-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-138-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-147-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-148-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-158-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-172-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-175-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-197-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-208-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-231-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-237-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-244-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'015': 'test',
#    '027': 'test',
#    '030': 'test',
#    '038': 'test',
#    '043': 'test',
#    '058': 'train',
#    '074': 'train',
#    '079': 'train',
#    '084': 'train',
#    '091': 'train',
#    '119': 'train',
#    '122': 'train',
#    '123': 'train',
#    '124': 'train',
#    '138': 'train',
#    '147': 'train',
#    '148': 'train',
#    '158': 'train',
#    '172': 'train',
#    '175': 'train',
#    '197': 'train',
#    '208': 'train',
#    '231': 'train',
#    '237': 'train',
#    '244': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 2,
#   'stimIDs': ['001',
#    '002',
#    '016',
#    '028',
#    '035',
#    '061',
#    '065',
#    '072',
#    '101',
#    '136',
#    '142',
#    '151',
#    '157',
#    '160',
#    '169',
#    '170',
#    '173',
#    '177',
#    '186',
#    '203',
#    '204',
#    '215',
#    '232',
#    '239',
#    '246'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-001-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-002-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-016-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-028-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-035-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-061-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-065-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-072-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-101-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-136-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-142-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-151-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-157-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-160-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-169-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-170-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-173-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-177-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-186-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-203-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-204-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-215-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-232-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-239-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-246-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'001': 'test',
#    '002': 'test',
#    '016': 'test',
#    '028': 'test',
#    '035': 'test',
#    '061': 'train',
#    '065': 'train',
#    '072': 'train',
#    '101': 'train',
#    '136': 'train',
#    '142': 'train',
#    '151': 'train',
#    '157': 'train',
#    '160': 'train',
#    '169': 'train',
#    '170': 'train',
#    '173': 'train',
#    '177': 'train',
#    '186': 'train',
#    '203': 'train',
#    '204': 'train',
#    '215': 'train',
#    '232': 'train',
#    '239': 'train',
#    '246': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 3,
#   'stimIDs': ['014',
#    '020',
#    '023',
#    '031',
#    '042',
#    '053',
#    '057',
#    '078',
#    '097',
#    '100',
#    '104',
#    '108',
#    '128',
#    '134',
#    '135',
#    '137',
#    '141',
#    '149',
#    '150',
#    '180',
#    '202',
#    '211',
#    '217',
#    '234',
#    '242'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-014-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-020-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-023-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-031-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-042-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-053-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-057-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-078-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-097-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-100-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-104-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-108-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-128-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-134-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-135-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-137-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-141-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-149-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-150-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-180-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-202-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-211-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-217-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-234-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-242-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'014': 'test',
#    '020': 'test',
#    '023': 'test',
#    '031': 'test',
#    '042': 'test',
#    '053': 'train',
#    '057': 'train',
#    '078': 'train',
#    '097': 'train',
#    '100': 'train',
#    '104': 'train',
#    '108': 'train',
#    '128': 'train',
#    '134': 'train',
#    '135': 'train',
#    '137': 'train',
#    '141': 'train',
#    '149': 'train',
#    '150': 'train',
#    '180': 'train',
#    '202': 'train',
#    '211': 'train',
#    '217': 'train',
#    '234': 'train',
#    '242': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 4,
#   'stimIDs': ['008',
#    '025',
#    '037',
#    '039',
#    '041',
#    '052',
#    '066',
#    '076',
#    '080',
#    '081',
#    '083',
#    '110',
#    '125',
#    '159',
#    '165',
#    '174',
#    '193',
#    '195',
#    '200',
#    '201',
#    '205',
#    '218',
#    '222',
#    '225',
#    '226'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-008-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-025-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-037-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-039-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-041-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-052-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-066-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-076-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-080-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-081-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-083-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-110-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-125-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-159-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-165-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-174-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-193-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-195-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-200-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-201-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-205-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-218-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-222-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-225-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-226-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'008': 'test',
#    '025': 'test',
#    '037': 'test',
#    '039': 'test',
#    '041': 'test',
#    '052': 'train',
#    '066': 'train',
#    '076': 'train',
#    '080': 'train',
#    '081': 'train',
#    '083': 'train',
#    '110': 'train',
#    '125': 'train',
#    '159': 'train',
#    '165': 'train',
#    '174': 'train',
#    '193': 'train',
#    '195': 'train',
#    '200': 'train',
#    '201': 'train',
#    '205': 'train',
#    '218': 'train',
#    '222': 'train',
#    '225': 'train',
#    '226': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 5,
#   'stimIDs': ['000',
#    '005',
#    '012',
#    '019',
#    '029',
#    '051',
#    '063',
#    '073',
#    '077',
#    '085',
#    '093',
#    '107',
#    '109',
#    '118',
#    '127',
#    '146',
#    '163',
#    '187',
#    '191',
#    '198',
#    '206',
#    '212',
#    '229',
#    '230',
#    '240'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-000-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-005-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-012-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-019-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-029-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-051-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-063-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-073-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-077-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-085-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-093-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-107-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-109-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-118-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-127-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-146-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-163-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-187-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-191-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-198-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-206-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-212-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-229-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-230-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-240-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'000': 'test',
#    '005': 'test',
#    '012': 'test',
#    '019': 'test',
#    '029': 'test',
#    '051': 'train',
#    '063': 'train',
#    '073': 'train',
#    '077': 'train',
#    '085': 'train',
#    '093': 'train',
#    '107': 'train',
#    '109': 'train',
#    '118': 'train',
#    '127': 'train',
#    '146': 'train',
#    '163': 'train',
#    '187': 'train',
#    '191': 'train',
#    '198': 'train',
#    '206': 'train',
#    '212': 'train',
#    '229': 'train',
#    '230': 'train',
#    '240': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 6,
#   'stimIDs': ['007',
#    '010',
#    '013',
#    '021',
#    '022',
#    '068',
#    '082',
#    '086',
#    '089',
#    '099',
#    '102',
#    '129',
#    '153',
#    '156',
#    '164',
#    '179',
#    '183',
#    '188',
#    '213',
#    '214',
#    '219',
#    '236',
#    '241',
#    '245',
#    '249'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-007-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-010-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-013-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-021-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-022-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-068-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-082-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-086-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-089-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-099-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-102-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-129-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-153-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-156-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-164-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-179-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-183-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-188-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-213-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-214-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-219-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-236-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-241-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-245-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-249-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'007': 'test',
#    '010': 'test',
#    '013': 'test',
#    '021': 'test',
#    '022': 'test',
#    '068': 'train',
#    '082': 'train',
#    '086': 'train',
#    '089': 'train',
#    '099': 'train',
#    '102': 'train',
#    '129': 'train',
#    '153': 'train',
#    '156': 'train',
#    '164': 'train',
#    '179': 'train',
#    '183': 'train',
#    '188': 'train',
#    '213': 'train',
#    '214': 'train',
#    '219': 'train',
#    '236': 'train',
#    '241': 'train',
#    '245': 'train',
#    '249': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 7,
#   'stimIDs': ['006',
#    '011',
#    '036',
#    '040',
#    '044',
#    '059',
#    '064',
#    '069',
#    '075',
#    '096',
#    '098',
#    '116',
#    '130',
#    '131',
#    '140',
#    '144',
#    '167',
#    '184',
#    '189',
#    '196',
#    '207',
#    '209',
#    '210',
#    '220',
#    '223'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-006-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-011-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-036-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-040-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-044-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-059-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-064-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-069-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-075-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-096-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-098-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-116-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-130-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-131-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-140-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-144-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-167-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-184-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-189-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-196-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-207-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-209-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-210-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-220-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-223-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'006': 'test',
#    '011': 'test',
#    '036': 'test',
#    '040': 'test',
#    '044': 'test',
#    '059': 'train',
#    '064': 'train',
#    '069': 'train',
#    '075': 'train',
#    '096': 'train',
#    '098': 'train',
#    '116': 'train',
#    '130': 'train',
#    '131': 'train',
#    '140': 'train',
#    '144': 'train',
#    '167': 'train',
#    '184': 'train',
#    '189': 'train',
#    '196': 'train',
#    '207': 'train',
#    '209': 'train',
#    '210': 'train',
#    '220': 'train',
#    '223': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 8,
#   'stimIDs': ['003',
#    '024',
#    '026',
#    '032',
#    '049',
#    '050',
#    '054',
#    '055',
#    '060',
#    '088',
#    '105',
#    '114',
#    '120',
#    '121',
#    '139',
#    '152',
#    '162',
#    '176',
#    '178',
#    '181',
#    '185',
#    '194',
#    '227',
#    '233',
#    '247'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-003-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-024-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-026-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-032-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-049-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-050-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-054-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-055-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-060-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-088-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-105-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-114-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-120-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-121-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-139-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-152-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-162-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-176-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-178-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-181-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-185-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-194-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-227-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-233-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-247-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'003': 'test',
#    '024': 'test',
#    '026': 'test',
#    '032': 'test',
#    '049': 'test',
#    '050': 'train',
#    '054': 'train',
#    '055': 'train',
#    '060': 'train',
#    '088': 'train',
#    '105': 'train',
#    '114': 'train',
#    '120': 'train',
#    '121': 'train',
#    '139': 'train',
#    '152': 'train',
#    '162': 'train',
#    '176': 'train',
#    '178': 'train',
#    '181': 'train',
#    '185': 'train',
#    '194': 'train',
#    '227': 'train',
#    '233': 'train',
#    '247': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimIDs': ['017',
#    '018',
#    '033',
#    '045',
#    '048',
#    '062',
#    '067',
#    '087',
#    '092',
#    '095',
#    '103',
#    '106',
#    '112',
#    '115',
#    '117',
#    '133',
#    '155',
#    '168',
#    '182',
#    '190',
#    '192',
#    '221',
#    '224',
#    '238',
#    '248'],
#   'stimURLS': ['https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-017-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-018-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-033-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-045-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-048-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-062-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-067-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-087-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-092-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-095-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-103-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-106-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-112-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-115-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-117-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-133-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-155-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-168-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-182-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-190-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-192-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-221-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-224-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-238-all.png',
#    'https://lax-drawing-furniture-all.s3.amazonaws.com/lax-drawing-furniture-248-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'017': 'test',
#    '018': 'test',
#    '033': 'test',
#    '045': 'test',
#    '048': 'test',
#    '062': 'train',
#    '067': 'train',
#    '087': 'train',
#    '092': 'train',
#    '095': 'train',
#    '103': 'train',
#    '106': 'train',
#    '112': 'train',
#    '115': 'train',
#    '117': 'train',
#    '133': 'train',
#    '155': 'train',
#    '168': 'train',
#    '182': 'train',
#    '190': 'train',
#    '192': 'train',
#    '221': 'train',
#    '224': 'train',
#    '238': 'train',
#    '248': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_furniture_all',
#   's3_bucket_url': 'https://lax-drawing-furniture-all.s3.amazonaws.com/',
#   'versionInd': 0}]

# %%
experiment_name
# Out:
# 'lax_drawing_furniture_all'

# %%
# Clear metadata collection

really_run = True;

if really_run:
    db.drop_collection(experiment_name)

# %%
## now, iterate through each version and insert into mongo
## loop through list of records and insert each into collection
reallyRun = True
if reallyRun:
    for (i,j) in enumerate(metadata):
        coll.insert_one(j)
        print('Inserted version {} of stimDict.'.format(j['versionInd']))
        clear_output(wait=True)

else:
    print('Did not insert any new data.')
# Out:
# Inserted version 0 of stimDict.

# %%
list(coll.find())
# Out:
# [{'_id': ObjectId('615b35a11e075f60ec090570'),
#   'partitionFamily': 0,
#   'splitNumber': 0,
#   'stimIDs': ['000',
#    '006',
#    '008',
#    '016',
#    '021',
#    '032',
#    '035',
#    '036',
#    '044',
#    '054',
#    '075',
#    '095',
#    '106',
#    '111',
#    '125',
#    '137',
#    '145',
#    '153',
#    '157',
#    '168',
#    '177',
#    '178',
#    '186',
#    '238',
#    '241'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-000-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-006-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-008-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-016-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-021-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-032-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-035-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-036-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-044-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-054-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-075-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-095-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-106-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-111-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-125-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-137-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-145-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-153-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-157-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-168-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-177-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-178-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-186-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-238-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-241-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'000': 'train',
#    '006': 'train',
#    '008': 'train',
#    '016': 'train',
#    '021': 'test',
#    '032': 'test',
#    '035': 'train',
#    '036': 'test',
#    '044': 'train',
#    '054': 'train',
#    '075': 'train',
#    '095': 'train',
#    '106': 'train',
#    '111': 'train',
#    '125': 'train',
#    '137': 'train',
#    '145': 'train',
#    '153': 'train',
#    '157': 'train',
#    '168': 'train',
#    '177': 'test',
#    '178': 'train',
#    '186': 'train',
#    '238': 'test',
#    '241': 'train'},
#   'numGames': 1,
#   'games': ['5283-26007298-3a61-4495-ab1e-cfecfd151cce'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090571'),
#   'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimIDs': ['009',
#    '017',
#    '019',
#    '039',
#    '041',
#    '050',
#    '064',
#    '065',
#    '096',
#    '103',
#    '115',
#    '139',
#    '144',
#    '171',
#    '187',
#    '194',
#    '196',
#    '200',
#    '204',
#    '208',
#    '212',
#    '223',
#    '229',
#    '239',
#    '240'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-009-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-017-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-019-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-039-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-041-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-050-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-064-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-065-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-096-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-103-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-115-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-139-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-144-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-171-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-187-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-194-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-196-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-200-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-204-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-208-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-212-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-223-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-229-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-239-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-240-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'009': 'test',
#    '017': 'train',
#    '019': 'train',
#    '039': 'test',
#    '041': 'train',
#    '050': 'train',
#    '064': 'train',
#    '065': 'train',
#    '096': 'train',
#    '103': 'test',
#    '115': 'test',
#    '139': 'train',
#    '144': 'train',
#    '171': 'train',
#    '187': 'train',
#    '194': 'train',
#    '196': 'train',
#    '200': 'train',
#    '204': 'train',
#    '208': 'test',
#    '212': 'train',
#    '223': 'train',
#    '229': 'train',
#    '239': 'train',
#    '240': 'train'},
#   'numGames': 1,
#   'games': ['5244-f3512ec4-1b94-403e-a262-b432e175db17'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090572'),
#   'partitionFamily': 0,
#   'splitNumber': 2,
#   'stimIDs': ['024',
#    '029',
#    '034',
#    '037',
#    '068',
#    '069',
#    '080',
#    '084',
#    '100',
#    '107',
#    '110',
#    '124',
#    '132',
#    '134',
#    '135',
#    '147',
#    '150',
#    '173',
#    '181',
#    '189',
#    '192',
#    '195',
#    '221',
#    '231',
#    '248'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-024-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-029-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-034-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-037-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-068-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-069-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-080-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-084-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-100-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-107-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-110-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-124-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-132-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-134-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-135-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-147-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-150-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-173-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-181-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-189-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-192-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-195-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-221-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-231-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-248-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'024': 'train',
#    '029': 'test',
#    '034': 'train',
#    '037': 'train',
#    '068': 'train',
#    '069': 'train',
#    '080': 'train',
#    '084': 'train',
#    '100': 'train',
#    '107': 'train',
#    '110': 'train',
#    '124': 'train',
#    '132': 'train',
#    '134': 'train',
#    '135': 'train',
#    '147': 'test',
#    '150': 'train',
#    '173': 'train',
#    '181': 'train',
#    '189': 'train',
#    '192': 'test',
#    '195': 'test',
#    '221': 'test',
#    '231': 'train',
#    '248': 'train'},
#   'numGames': 1,
#   'games': ['3445-18d32844-a8cc-4dc5-a283-b8e6f975431b'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090573'),
#   'partitionFamily': 0,
#   'splitNumber': 3,
#   'stimIDs': ['011',
#    '020',
#    '027',
#    '049',
#    '053',
#    '055',
#    '058',
#    '059',
#    '070',
#    '072',
#    '105',
#    '113',
#    '130',
#    '133',
#    '146',
#    '152',
#    '158',
#    '174',
#    '176',
#    '215',
#    '220',
#    '222',
#    '235',
#    '236',
#    '244'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-011-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-020-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-027-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-049-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-053-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-055-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-058-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-059-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-070-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-072-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-105-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-113-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-130-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-133-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-146-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-152-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-158-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-174-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-176-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-215-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-220-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-222-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-235-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-236-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-244-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'011': 'train',
#    '020': 'train',
#    '027': 'train',
#    '049': 'train',
#    '053': 'train',
#    '055': 'train',
#    '058': 'test',
#    '059': 'train',
#    '070': 'test',
#    '072': 'test',
#    '105': 'train',
#    '113': 'train',
#    '130': 'train',
#    '133': 'train',
#    '146': 'train',
#    '152': 'train',
#    '158': 'train',
#    '174': 'test',
#    '176': 'train',
#    '215': 'train',
#    '220': 'train',
#    '222': 'train',
#    '235': 'test',
#    '236': 'train',
#    '244': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090574'),
#   'partitionFamily': 0,
#   'splitNumber': 4,
#   'stimIDs': ['003',
#    '015',
#    '045',
#    '062',
#    '073',
#    '078',
#    '085',
#    '089',
#    '093',
#    '120',
#    '126',
#    '129',
#    '136',
#    '159',
#    '164',
#    '165',
#    '193',
#    '205',
#    '209',
#    '213',
#    '214',
#    '225',
#    '234',
#    '237',
#    '246'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-003-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-015-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-045-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-062-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-073-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-078-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-085-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-089-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-093-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-120-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-126-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-129-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-136-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-159-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-164-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-165-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-193-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-205-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-209-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-213-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-214-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-225-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-234-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-237-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-246-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'003': 'train',
#    '015': 'train',
#    '045': 'train',
#    '062': 'train',
#    '073': 'train',
#    '078': 'train',
#    '085': 'train',
#    '089': 'train',
#    '093': 'train',
#    '120': 'train',
#    '126': 'train',
#    '129': 'train',
#    '136': 'train',
#    '159': 'train',
#    '164': 'train',
#    '165': 'test',
#    '193': 'test',
#    '205': 'test',
#    '209': 'test',
#    '213': 'train',
#    '214': 'train',
#    '225': 'train',
#    '234': 'train',
#    '237': 'train',
#    '246': 'test'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090575'),
#   'partitionFamily': 0,
#   'splitNumber': 5,
#   'stimIDs': ['002',
#    '040',
#    '046',
#    '051',
#    '056',
#    '082',
#    '091',
#    '094',
#    '099',
#    '104',
#    '121',
#    '128',
#    '149',
#    '151',
#    '154',
#    '169',
#    '170',
#    '172',
#    '175',
#    '182',
#    '185',
#    '198',
#    '217',
#    '243',
#    '247'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-002-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-040-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-046-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-051-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-056-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-082-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-091-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-094-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-099-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-104-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-121-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-128-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-149-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-151-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-154-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-169-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-170-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-172-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-175-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-182-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-185-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-198-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-217-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-243-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-247-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'002': 'train',
#    '040': 'train',
#    '046': 'train',
#    '051': 'train',
#    '056': 'train',
#    '082': 'test',
#    '091': 'train',
#    '094': 'train',
#    '099': 'test',
#    '104': 'train',
#    '121': 'train',
#    '128': 'train',
#    '149': 'train',
#    '151': 'train',
#    '154': 'train',
#    '169': 'train',
#    '170': 'train',
#    '172': 'test',
#    '175': 'test',
#    '182': 'train',
#    '185': 'test',
#    '198': 'train',
#    '217': 'train',
#    '243': 'train',
#    '247': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090576'),
#   'partitionFamily': 0,
#   'splitNumber': 6,
#   'stimIDs': ['012',
#    '018',
#    '028',
#    '033',
#    '043',
#    '048',
#    '060',
#    '071',
#    '081',
#    '086',
#    '087',
#    '090',
#    '101',
#    '108',
#    '119',
#    '140',
#    '143',
#    '148',
#    '160',
#    '179',
#    '183',
#    '188',
#    '191',
#    '197',
#    '202'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-012-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-018-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-028-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-033-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-043-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-048-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-060-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-071-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-081-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-086-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-087-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-090-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-101-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-108-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-119-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-140-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-143-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-148-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-160-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-179-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-183-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-188-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-191-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-197-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-202-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'012': 'train',
#    '018': 'train',
#    '028': 'train',
#    '033': 'train',
#    '043': 'train',
#    '048': 'train',
#    '060': 'train',
#    '071': 'train',
#    '081': 'test',
#    '086': 'train',
#    '087': 'test',
#    '090': 'train',
#    '101': 'train',
#    '108': 'train',
#    '119': 'train',
#    '140': 'test',
#    '143': 'train',
#    '148': 'test',
#    '160': 'train',
#    '179': 'train',
#    '183': 'train',
#    '188': 'train',
#    '191': 'train',
#    '197': 'test',
#    '202': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090577'),
#   'partitionFamily': 0,
#   'splitNumber': 7,
#   'stimIDs': ['007',
#    '010',
#    '014',
#    '023',
#    '025',
#    '026',
#    '038',
#    '047',
#    '057',
#    '063',
#    '076',
#    '079',
#    '092',
#    '097',
#    '122',
#    '161',
#    '163',
#    '190',
#    '199',
#    '206',
#    '210',
#    '211',
#    '216',
#    '218',
#    '233'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-007-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-010-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-014-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-023-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-025-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-026-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-038-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-047-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-057-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-063-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-076-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-079-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-092-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-097-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-122-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-161-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-163-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-190-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-199-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-206-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-210-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-211-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-216-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-218-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-233-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'007': 'train',
#    '010': 'train',
#    '014': 'train',
#    '023': 'train',
#    '025': 'test',
#    '026': 'train',
#    '038': 'train',
#    '047': 'test',
#    '057': 'train',
#    '063': 'train',
#    '076': 'train',
#    '079': 'test',
#    '092': 'train',
#    '097': 'train',
#    '122': 'train',
#    '161': 'train',
#    '163': 'train',
#    '190': 'train',
#    '199': 'train',
#    '206': 'train',
#    '210': 'train',
#    '211': 'test',
#    '216': 'test',
#    '218': 'train',
#    '233': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090578'),
#   'partitionFamily': 0,
#   'splitNumber': 8,
#   'stimIDs': ['001',
#    '004',
#    '030',
#    '052',
#    '066',
#    '077',
#    '083',
#    '116',
#    '117',
#    '118',
#    '131',
#    '138',
#    '142',
#    '155',
#    '162',
#    '167',
#    '180',
#    '184',
#    '201',
#    '203',
#    '207',
#    '224',
#    '227',
#    '230',
#    '249'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-001-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-004-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-030-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-052-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-066-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-077-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-083-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-116-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-117-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-118-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-131-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-138-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-142-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-155-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-162-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-167-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-180-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-184-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-201-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-203-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-207-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-224-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-227-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-230-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-249-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'001': 'train',
#    '004': 'train',
#    '030': 'train',
#    '052': 'train',
#    '066': 'train',
#    '077': 'test',
#    '083': 'train',
#    '116': 'train',
#    '117': 'test',
#    '118': 'train',
#    '131': 'train',
#    '138': 'train',
#    '142': 'test',
#    '155': 'train',
#    '162': 'train',
#    '167': 'test',
#    '180': 'train',
#    '184': 'train',
#    '201': 'train',
#    '203': 'train',
#    '207': 'train',
#    '224': 'train',
#    '227': 'train',
#    '230': 'test',
#    '249': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b35a21e075f60ec090579'),
#   'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimIDs': ['005',
#    '013',
#    '022',
#    '031',
#    '042',
#    '061',
#    '067',
#    '074',
#    '088',
#    '098',
#    '102',
#    '109',
#    '112',
#    '114',
#    '123',
#    '127',
#    '141',
#    '156',
#    '166',
#    '219',
#    '226',
#    '228',
#    '232',
#    '242',
#    '245'],
#   'stimURLS': ['https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-005-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-013-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-022-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-031-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-042-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-061-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-067-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-074-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-088-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-098-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-102-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-109-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-112-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-114-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-123-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-127-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-141-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-156-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-166-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-219-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-226-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-228-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-232-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-242-all.png',
#    'https://lax-structures-castle-all.s3.amazonaws.com/lax-structures-castle-245-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'005': 'train',
#    '013': 'train',
#    '022': 'train',
#    '031': 'train',
#    '042': 'train',
#    '061': 'train',
#    '067': 'test',
#    '074': 'train',
#    '088': 'test',
#    '098': 'train',
#    '102': 'train',
#    '109': 'train',
#    '112': 'train',
#    '114': 'train',
#    '123': 'train',
#    '127': 'test',
#    '141': 'train',
#    '156': 'train',
#    '166': 'train',
#    '219': 'train',
#    '226': 'train',
#    '228': 'train',
#    '232': 'test',
#    '242': 'test',
#    '245': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_castle_all',
#   's3_bucket_url': 'https://lax-structures-castle-all.s3.amazonaws.com/',
#   'versionInd': 0}]

# %% [markdown]
# ## Test which versions have been run
#
# This grabs the dataframe created by data generator, to see which records need to be run more times.
#
# It wipes the metadata from mongo, and replaces it with individual records for each additional partition that needs to be run.

# %%
version = 'procedural'
# version = 'categorization'

# %%
# WARNING: THIS JUST GRABS A LOCAL CSV. ENSURE YOU HAVE CREATED THIS WITH DATA GENERATOR NOTEBOOK

run_results_through_data_generator = True


if run_results_through_data_generator:
    results_csv_directory = "../../results/csv"
    # print("Possible CSV results files to load:")
    # print(os.listdir(results_csv_directory))

    result_csv = 'lax-tower-4-block-unique-silhouettes-' + version +'-pilot_3.csv'

    df_trial = pd.read_csv(os.path.join(results_csv_directory, result_csv))

# %%
complete_counts = (df_trial.groupby(['partitionFamily','splitNumber']).count()/13)['datatype'].reset_index()
complete_counts
# Out:
#     partitionFamily  splitNumber  datatype
# 0               0.0          0.0       6.0
# 1               0.0          1.0       5.0
# 2               0.0          2.0       5.0
# 3               0.0          3.0       5.0
# 4               0.0          4.0       5.0
# 5               0.0          5.0       5.0
# 6               0.0          6.0       5.0
# 7               0.0          7.0       5.0
# 8               0.0          8.0       5.0
# 9               0.0          9.0       5.0
# 10              1.0          0.0       5.0
# 11              1.0          1.0       5.0
# 12              1.0          2.0       5.0
# 13              1.0          3.0       5.0
# 14              1.0          4.0       5.0
# 15              1.0          5.0       5.0
# 16              1.0          6.0       5.0
# 17              1.0          7.0       5.0
# 18              1.0          8.0       5.0
# 19              1.0          9.0       5.0

# %%
# add a record in metadata for each additional time it needs to be run

n_expected = 5

extra_metadata = []

for f in range(0, n_families):
    for s in range(0,n_splits):
        
        n_completed = complete_counts[(complete_counts.partitionFamily == f) & (complete_counts.splitNumber == s)]\
            .reset_index().loc[0,'datatype']
        
        i = n_completed
        
        while i < n_expected:
            
            i = i + 1

            stim_numbers = list(silhouette_superset.groupby('family_'+str(f)).get_group(s)['tower_number_str'])
    #         print(stim_numbers)
            extra_metadata.append(
                {
                    'partitionFamily': f,
                    'splitNumber': s,
                    'stimNumbers': stim_numbers,
                    'ntrials': len(stim_numbers),
                    'stimGroups': {n: silhouette_superset.groupby('family_'+str(f)).get_group(s).reset_index().loc[i,'group'] for i, n in enumerate(stim_numbers)},
                    'numGames': 0,
                    'games': [],
                    'experimentType': 'prior_elicitation',
                    'experimentName': experiment_name,
                    's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
                    'versionInd': versionInd,
                    'extra_metadata_index': i
                })

# %%
print(str(len(extra_metadata)) + ' extra records to upload')
# Out:
# 0 extra records to upload

# %%
# Delete metadata from db
really_run = False

if really_run:
    db.drop_collection(experiment_name)

# %%
## now, iterate through each version and insert into mongo
## loop through list of records and insert each into collection
reallyRun = True
if reallyRun:
    for (i,j) in enumerate(extra_metadata):        
        coll.insert_one(j)
        print('Inserted version {} of stimDict.'.format(j['versionInd']))
        clear_output(wait=True)

else:
    print('Did not insert any new data.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-e0d09d877104> in <module>
#       3 reallyRun = True
#       4 if reallyRun:
# ----> 5     for (i,j) in enumerate(extra_metadata):
#       6         coll.insert_one(j)
#       7         print('Inserted version {} of stimDict.'.format(j['versionInd']))
#
# NameError: name 'extra_metadata' is not defined

# %%
list(coll.find())
# Out:
# [{'_id': ObjectId('615b36761e075f60ec090591'),
#   'partitionFamily': 0,
#   'splitNumber': 0,
#   'stimIDs': ['004',
#    '009',
#    '034',
#    '046',
#    '047',
#    '056',
#    '070',
#    '071',
#    '090',
#    '094',
#    '111',
#    '113',
#    '126',
#    '132',
#    '143',
#    '145',
#    '154',
#    '161',
#    '166',
#    '171',
#    '199',
#    '216',
#    '228',
#    '235',
#    '243'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-004-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-009-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-034-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-046-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-047-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-056-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-070-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-071-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-090-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-094-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-111-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-113-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-126-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-132-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-143-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-145-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-154-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-161-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-166-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-171-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-199-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-216-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-228-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-235-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-243-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'004': 'test',
#    '009': 'test',
#    '034': 'test',
#    '046': 'test',
#    '047': 'test',
#    '056': 'train',
#    '070': 'train',
#    '071': 'train',
#    '090': 'train',
#    '094': 'train',
#    '111': 'train',
#    '113': 'train',
#    '126': 'train',
#    '132': 'train',
#    '143': 'train',
#    '145': 'train',
#    '154': 'train',
#    '161': 'train',
#    '166': 'train',
#    '171': 'train',
#    '199': 'train',
#    '216': 'train',
#    '228': 'train',
#    '235': 'train',
#    '243': 'train'},
#   'numGames': 1,
#   'games': ['7666-18fb556c-700f-48c6-a142-1b489246da56'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36761e075f60ec090592'),
#   'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimIDs': ['015',
#    '027',
#    '030',
#    '038',
#    '043',
#    '058',
#    '074',
#    '079',
#    '084',
#    '091',
#    '119',
#    '122',
#    '123',
#    '124',
#    '138',
#    '147',
#    '148',
#    '158',
#    '172',
#    '175',
#    '197',
#    '208',
#    '231',
#    '237',
#    '244'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-015-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-027-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-030-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-038-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-043-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-058-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-074-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-079-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-084-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-091-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-119-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-122-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-123-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-124-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-138-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-147-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-148-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-158-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-172-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-175-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-197-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-208-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-231-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-237-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-244-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'015': 'test',
#    '027': 'test',
#    '030': 'test',
#    '038': 'test',
#    '043': 'test',
#    '058': 'train',
#    '074': 'train',
#    '079': 'train',
#    '084': 'train',
#    '091': 'train',
#    '119': 'train',
#    '122': 'train',
#    '123': 'train',
#    '124': 'train',
#    '138': 'train',
#    '147': 'train',
#    '148': 'train',
#    '158': 'train',
#    '172': 'train',
#    '175': 'train',
#    '197': 'train',
#    '208': 'train',
#    '231': 'train',
#    '237': 'train',
#    '244': 'train'},
#   'numGames': 1,
#   'games': ['0807-044805aa-c75b-4cca-bc35-1efafd9163cc'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36761e075f60ec090593'),
#   'partitionFamily': 0,
#   'splitNumber': 2,
#   'stimIDs': ['001',
#    '002',
#    '016',
#    '028',
#    '035',
#    '061',
#    '065',
#    '072',
#    '101',
#    '136',
#    '142',
#    '151',
#    '157',
#    '160',
#    '169',
#    '170',
#    '173',
#    '177',
#    '186',
#    '203',
#    '204',
#    '215',
#    '232',
#    '239',
#    '246'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-001-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-002-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-016-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-028-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-035-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-061-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-065-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-072-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-101-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-136-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-142-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-151-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-157-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-160-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-169-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-170-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-173-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-177-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-186-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-203-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-204-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-215-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-232-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-239-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-246-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'001': 'test',
#    '002': 'test',
#    '016': 'test',
#    '028': 'test',
#    '035': 'test',
#    '061': 'train',
#    '065': 'train',
#    '072': 'train',
#    '101': 'train',
#    '136': 'train',
#    '142': 'train',
#    '151': 'train',
#    '157': 'train',
#    '160': 'train',
#    '169': 'train',
#    '170': 'train',
#    '173': 'train',
#    '177': 'train',
#    '186': 'train',
#    '203': 'train',
#    '204': 'train',
#    '215': 'train',
#    '232': 'train',
#    '239': 'train',
#    '246': 'train'},
#   'numGames': 1,
#   'games': ['4890-4cd7ba9b-8c8a-4dad-a7ef-0d1d56ca07b0'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36761e075f60ec090594'),
#   'partitionFamily': 0,
#   'splitNumber': 3,
#   'stimIDs': ['014',
#    '020',
#    '023',
#    '031',
#    '042',
#    '053',
#    '057',
#    '078',
#    '097',
#    '100',
#    '104',
#    '108',
#    '128',
#    '134',
#    '135',
#    '137',
#    '141',
#    '149',
#    '150',
#    '180',
#    '202',
#    '211',
#    '217',
#    '234',
#    '242'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-014-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-020-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-023-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-031-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-042-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-053-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-057-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-078-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-097-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-100-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-104-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-108-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-128-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-134-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-135-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-137-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-141-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-149-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-150-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-180-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-202-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-211-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-217-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-234-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-242-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'014': 'test',
#    '020': 'test',
#    '023': 'test',
#    '031': 'test',
#    '042': 'test',
#    '053': 'train',
#    '057': 'train',
#    '078': 'train',
#    '097': 'train',
#    '100': 'train',
#    '104': 'train',
#    '108': 'train',
#    '128': 'train',
#    '134': 'train',
#    '135': 'train',
#    '137': 'train',
#    '141': 'train',
#    '149': 'train',
#    '150': 'train',
#    '180': 'train',
#    '202': 'train',
#    '211': 'train',
#    '217': 'train',
#    '234': 'train',
#    '242': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36761e075f60ec090595'),
#   'partitionFamily': 0,
#   'splitNumber': 4,
#   'stimIDs': ['008',
#    '025',
#    '037',
#    '039',
#    '041',
#    '052',
#    '066',
#    '076',
#    '080',
#    '081',
#    '083',
#    '110',
#    '125',
#    '159',
#    '165',
#    '174',
#    '193',
#    '195',
#    '200',
#    '201',
#    '205',
#    '218',
#    '222',
#    '225',
#    '226'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-008-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-025-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-037-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-039-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-041-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-052-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-066-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-076-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-080-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-081-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-083-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-110-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-125-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-159-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-165-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-174-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-193-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-195-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-200-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-201-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-205-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-218-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-222-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-225-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-226-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'008': 'test',
#    '025': 'test',
#    '037': 'test',
#    '039': 'test',
#    '041': 'test',
#    '052': 'train',
#    '066': 'train',
#    '076': 'train',
#    '080': 'train',
#    '081': 'train',
#    '083': 'train',
#    '110': 'train',
#    '125': 'train',
#    '159': 'train',
#    '165': 'train',
#    '174': 'train',
#    '193': 'train',
#    '195': 'train',
#    '200': 'train',
#    '201': 'train',
#    '205': 'train',
#    '218': 'train',
#    '222': 'train',
#    '225': 'train',
#    '226': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36771e075f60ec090596'),
#   'partitionFamily': 0,
#   'splitNumber': 5,
#   'stimIDs': ['000',
#    '005',
#    '012',
#    '019',
#    '029',
#    '051',
#    '063',
#    '073',
#    '077',
#    '085',
#    '093',
#    '107',
#    '109',
#    '118',
#    '127',
#    '146',
#    '163',
#    '187',
#    '191',
#    '198',
#    '206',
#    '212',
#    '229',
#    '230',
#    '240'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-000-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-005-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-012-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-019-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-029-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-051-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-063-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-073-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-077-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-085-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-093-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-107-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-109-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-118-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-127-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-146-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-163-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-187-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-191-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-198-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-206-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-212-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-229-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-230-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-240-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'000': 'test',
#    '005': 'test',
#    '012': 'test',
#    '019': 'test',
#    '029': 'test',
#    '051': 'train',
#    '063': 'train',
#    '073': 'train',
#    '077': 'train',
#    '085': 'train',
#    '093': 'train',
#    '107': 'train',
#    '109': 'train',
#    '118': 'train',
#    '127': 'train',
#    '146': 'train',
#    '163': 'train',
#    '187': 'train',
#    '191': 'train',
#    '198': 'train',
#    '206': 'train',
#    '212': 'train',
#    '229': 'train',
#    '230': 'train',
#    '240': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36771e075f60ec090597'),
#   'partitionFamily': 0,
#   'splitNumber': 6,
#   'stimIDs': ['007',
#    '010',
#    '013',
#    '021',
#    '022',
#    '068',
#    '082',
#    '086',
#    '089',
#    '099',
#    '102',
#    '129',
#    '153',
#    '156',
#    '164',
#    '179',
#    '183',
#    '188',
#    '213',
#    '214',
#    '219',
#    '236',
#    '241',
#    '245',
#    '249'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-007-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-010-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-013-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-021-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-022-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-068-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-082-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-086-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-089-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-099-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-102-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-129-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-153-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-156-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-164-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-179-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-183-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-188-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-213-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-214-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-219-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-236-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-241-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-245-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-249-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'007': 'test',
#    '010': 'test',
#    '013': 'test',
#    '021': 'test',
#    '022': 'test',
#    '068': 'train',
#    '082': 'train',
#    '086': 'train',
#    '089': 'train',
#    '099': 'train',
#    '102': 'train',
#    '129': 'train',
#    '153': 'train',
#    '156': 'train',
#    '164': 'train',
#    '179': 'train',
#    '183': 'train',
#    '188': 'train',
#    '213': 'train',
#    '214': 'train',
#    '219': 'train',
#    '236': 'train',
#    '241': 'train',
#    '245': 'train',
#    '249': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36771e075f60ec090598'),
#   'partitionFamily': 0,
#   'splitNumber': 7,
#   'stimIDs': ['006',
#    '011',
#    '036',
#    '040',
#    '044',
#    '059',
#    '064',
#    '069',
#    '075',
#    '096',
#    '098',
#    '116',
#    '130',
#    '131',
#    '140',
#    '144',
#    '167',
#    '184',
#    '189',
#    '196',
#    '207',
#    '209',
#    '210',
#    '220',
#    '223'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-006-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-011-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-036-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-040-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-044-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-059-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-064-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-069-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-075-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-096-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-098-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-116-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-130-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-131-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-140-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-144-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-167-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-184-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-189-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-196-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-207-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-209-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-210-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-220-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-223-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'006': 'test',
#    '011': 'test',
#    '036': 'test',
#    '040': 'test',
#    '044': 'test',
#    '059': 'train',
#    '064': 'train',
#    '069': 'train',
#    '075': 'train',
#    '096': 'train',
#    '098': 'train',
#    '116': 'train',
#    '130': 'train',
#    '131': 'train',
#    '140': 'train',
#    '144': 'train',
#    '167': 'train',
#    '184': 'train',
#    '189': 'train',
#    '196': 'train',
#    '207': 'train',
#    '209': 'train',
#    '210': 'train',
#    '220': 'train',
#    '223': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36771e075f60ec090599'),
#   'partitionFamily': 0,
#   'splitNumber': 8,
#   'stimIDs': ['003',
#    '024',
#    '026',
#    '032',
#    '049',
#    '050',
#    '054',
#    '055',
#    '060',
#    '088',
#    '105',
#    '114',
#    '120',
#    '121',
#    '139',
#    '152',
#    '162',
#    '176',
#    '178',
#    '181',
#    '185',
#    '194',
#    '227',
#    '233',
#    '247'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-003-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-024-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-026-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-032-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-049-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-050-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-054-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-055-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-060-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-088-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-105-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-114-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-120-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-121-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-139-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-152-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-162-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-176-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-178-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-181-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-185-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-194-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-227-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-233-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-247-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'003': 'test',
#    '024': 'test',
#    '026': 'test',
#    '032': 'test',
#    '049': 'test',
#    '050': 'train',
#    '054': 'train',
#    '055': 'train',
#    '060': 'train',
#    '088': 'train',
#    '105': 'train',
#    '114': 'train',
#    '120': 'train',
#    '121': 'train',
#    '139': 'train',
#    '152': 'train',
#    '162': 'train',
#    '176': 'train',
#    '178': 'train',
#    '181': 'train',
#    '185': 'train',
#    '194': 'train',
#    '227': 'train',
#    '233': 'train',
#    '247': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('615b36771e075f60ec09059a'),
#   'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimIDs': ['017',
#    '018',
#    '033',
#    '045',
#    '048',
#    '062',
#    '067',
#    '087',
#    '092',
#    '095',
#    '103',
#    '106',
#    '112',
#    '115',
#    '117',
#    '133',
#    '155',
#    '168',
#    '182',
#    '190',
#    '192',
#    '221',
#    '224',
#    '238',
#    '248'],
#   'stimURLS': ['https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-017-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-018-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-033-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-045-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-048-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-062-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-067-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-087-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-092-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-095-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-103-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-106-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-112-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-115-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-117-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-133-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-155-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-168-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-182-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-190-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-192-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-221-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-224-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-238-all.png',
#    'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/lax-drawing-nuts-bolts-248-all.png'],
#   'ntrials': 25,
#   'stimGroups': {'017': 'test',
#    '018': 'test',
#    '033': 'test',
#    '045': 'test',
#    '048': 'test',
#    '062': 'train',
#    '067': 'train',
#    '087': 'train',
#    '092': 'train',
#    '095': 'train',
#    '103': 'train',
#    '106': 'train',
#    '112': 'train',
#    '115': 'train',
#    '117': 'train',
#    '133': 'train',
#    '155': 'train',
#    '168': 'train',
#    '182': 'train',
#    '190': 'train',
#    '192': 'train',
#    '221': 'train',
#    '224': 'train',
#    '238': 'train',
#    '248': 'train'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_nuts-bolts_all',
#   's3_bucket_url': 'https://lax-drawing-nuts-bolts-all.s3.amazonaws.com/',
#   'versionInd': 0}]

# %%
experiment_name

# %%
# metadata_pre_top_up = pd.DataFrame(coll.find())

# metadata_pre_top_up.to_csv('./metadata/first_batch_procedural.csv')

# %%
experiment_name
# Out:
# 'ca_prior_elicitation_4_block_unique_silhouettes_categorization'
